# %% [markdown]
# #  Pokec Network Study (sampled version)
#
# We’re going to:
# 1. Load the giant Pokec friendship graph
# 2. Extract a connected 10 000-node subgraph using BFS sampling
# 3. Load and clean user attributes
# 4. Attach those attributes to the sampled graph
# 5. Visualize it and confirm it behaves like the full network

# %%
# ==================================
#  Imports
# ==================================
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import os

plt.style.use("seaborn-v0_8")

# %% [markdown]
# ## 1️ Load a partial graph and sample a connected subgraph
# The full Pokec dataset has 1.6 M nodes and 30 M edges — too heavy.
# We load the first few hundred thousand edges, then extract a BFS subgraph (~10 k nodes).

# %%
import os
import networkx as nx
import random
import numpy as np

# Fixer la graine pour reproductibilité
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

GRAPH_PATH = "dataset/pokec_subgraph_relationships.gpickle"

def load_partial_graph(path, max_edges=500_000):
    G = nx.Graph()
    with open(path) as f:
        for i, line in enumerate(f):
            if i >= max_edges:
                break
            try:
                u, v = map(int, line.strip().split('\t'))
                G.add_edge(u, v)
            except:
                continue
    return G

# --- Sauvegarde / Chargement compatible NetworkX 3.x ---
def save_graph_gpickle(G, path):
    """Save graph using pickle (compatible with all NetworkX versions)."""
    import pickle
    with open(path, "wb") as f:
        pickle.dump(G, f)

def load_graph_gpickle(path):
    """Load graph using pickle (compatible with all NetworkX versions)."""
    import pickle
    with open(path, "rb") as f:
        return pickle.load(f)

# --- Vérifie si le graphe est déjà sauvegardé ---
if os.path.exists(GRAPH_PATH):
    print(f"📂 Loading saved subgraph from {GRAPH_PATH}...")
    H = load_graph_gpickle(GRAPH_PATH)
    print(f"✅ Loaded saved graph: {H.number_of_nodes()} nodes, {H.number_of_edges()} edges")

else:
    print("⏳ Loading part of Pokec edges...")
    G = load_partial_graph("dataset/soc-pokec-relationships.txt", max_edges=500_000)
    print(f"✅ Partial graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

    # BFS sample autour d’un nœud choisi aléatoirement mais déterministe
    start = random.choice(list(G.nodes()))
    sub_nodes = list(nx.bfs_tree(G, start, depth_limit=3).nodes())
    H = G.subgraph(sub_nodes).copy()

    # Si le graphe est trop petit, élargir la recherche
    if H.number_of_nodes() < 1000:
        print(f"Too small ({H.number_of_nodes()} nodes), trying deeper BFS...")
        sub_nodes = list(nx.bfs_tree(G, start, depth_limit=4).nodes())
        H = G.subgraph(sub_nodes).copy()

    print(f"✅ BFS subgraph: {H.number_of_nodes()} nodes, {H.number_of_edges()} edges")

    # 💾 Sauvegarder avec pickle
    os.makedirs(os.path.dirname(GRAPH_PATH), exist_ok=True)
    save_graph_gpickle(H, GRAPH_PATH)
    print(f"💾 Saved subgraph to {GRAPH_PATH}")
# Out:
# 📂 Loading saved subgraph from dataset/pokec_subgraph_relationships.gpickle...
# ✅ Loaded saved graph: 10681 nodes, 23726 edges

# %% [markdown]
# ## 2️ Load and clean user features

# %% [markdown]
# ##  Phase Préliminaire — Pré-traitement des données avant toute analyse GNN
#
# Avant toute analyse de graphe de type **Graph Neural Network (GNN)** sur des données réelles, l'étape cruciale est le **pré-traitement**.
#
# Principe fondamental : si les données d’entrée sont mauvaises (*GIGO : Garbage In, Garbage Out*), les résultats le seront aussi.
# Les GNN exploitent les **attributs de nœuds** ; ces features doivent donc être propres, encodées et standardisées.
#
# Cette section applique les principes de *Data Mining* classiques :
# 1. Nettoyage des données (valeurs manquantes, doublons, erreurs)
# 2. Encodage des variables catégorielles
# 3. Standardisation des numériques
# 4. Nettoyage structurel du graphe (self-loops, nœuds isolés)
# 5. Sauvegarde du graphe et des features prêtes pour l’analyse

# %%
import pandas as pd
import numpy as np
import networkx as nx
import os

PROFILES_RAW = "dataset/soc-pokec-profiles.txt"
GRAPH_PREP_PATH = "dataset/pokec_graph_preprocessed.gpickle"
FEATURES_PREP_PATH = "dataset/pokec_features_preprocessed.parquet"

print("📦 Préparation complète à partir du fichier brut Pokec...")
# Out:
# 📦 Préparation complète à partir du fichier brut Pokec...

# %% [markdown]
# ###  Étape 1 : Lecture et nettoyage du fichier brut
#
# On sélectionne les colonnes utiles, corrige les types, et simplifie les textes libres
# (`smoker`, `drinker`) pour obtenir des catégories cohérentes.

# %%
profiles = pd.read_csv(PROFILES_RAW, sep="\t", header=None, low_memory=False)

cols = [
    "user_id","public","completion","gender","region",
    "last_login","registration","age","body","work_field",
    "languages","hobbies","interests","music","movies",
    "religion","cars","politics","looking_for","smoker","drinker"
]
profiles.columns = cols + list(range(len(cols), profiles.shape[1]))

df = profiles[["user_id","gender","age","region","smoker","drinker","completion"]].copy()
df = df.dropna(subset=["user_id"])
df["user_id"] = df["user_id"].astype(int)

# genre, région, âge
df["gender"] = df["gender"].map({1.0:"male", 0.0:"female"}).fillna("unknown")
df["region"] = df["region"].astype(str).str.split(",").str[0]
df["age"] = pd.to_numeric(df["age"], errors="coerce").replace(0, np.nan)

# simplification des champs texte
def simplify_text(val):
    if not isinstance(val, str):
        return "unknown"
    val = val.lower()
    if any(k in val for k in ["ne", "nie", "vobec"]):
        return "no"
    if any(k in val for k in ["ano", "áno", "hej", "pijem", "obcas", "občas"]):
        return "yes"
    return "unknown"

df["smoker_clean"] = df["smoker"].apply(simplify_text)
df["drinker_clean"] = df["drinker"].apply(simplify_text)

print("✅ Profils bruts nettoyés :", len(df), "lignes")
print(df.head(3))
# Out:
# ✅ Profils bruts nettoyés : 1632803 lignes
#    user_id  gender   age         region  \
# 0        1    male  26.0  zilinsky kraj
# 1        2  female   NaN  zilinsky kraj
# 2       16    male  23.0  zilinsky kraj
#
#                                               smoker                drinker  \
# 0                                                NaN                    NaN
# 1  zakladne, ale som uz na strednej skole dufam z...  cierna, modra, ruzova
# 2                      coskoro 24.5 alebo 31.9    :d   biela, modra, zelena
#
#    completion smoker_clean drinker_clean
# 0          14      unknown       unknown
# 1          62           no       unknown
# 2          64      unknown       unknown

# %% [markdown]
# ###  Étape 2 : Nettoyage structurel du graphe
#
# Avant toute extraction de features, on doit vérifier que le graphe n’a ni doublons ni boucles ;
# les nœuds isolés sont supprimés pour ne conserver qu’une composante cohérente.

# %%
H.remove_edges_from(nx.selfloop_edges(H))
H = nx.Graph(H)
isolates = list(nx.isolates(H))
if isolates:
    H.remove_nodes_from(isolates)
print(f"Graphe nettoyé : {H.number_of_nodes()} nœuds, {H.number_of_edges()} arêtes.")
# Out:
# Graphe nettoyé : 10681 nœuds, 23726 arêtes.

# %% [markdown]
# ### ⚙️ Étape 3 : Encodage One-Hot et standardisation (Z-score)
#
# Les variables catégorielles sont encodées, les numériques standardisées ;
# on obtient une matrice homogène exploitable par un GNN.

# %%
# Préparation des features et normalisation (safe, sans chained assignment)
feat = df[df["user_id"].isin(H.nodes())].copy()

# 1) conversions numériques
feat["age"] = pd.to_numeric(feat["age"], errors="coerce")
feat["completion"] = pd.to_numeric(feat["completion"], errors="coerce")

# 2) imputation par la moyenne (AVANT standardisation)
feat = feat.assign(
    age=feat["age"].fillna(feat["age"].mean()),
    completion=feat["completion"].fillna(feat["completion"].mean())
)

# ...
# 3) Standardisation numérique
feat = feat.assign(
    age_z=(feat["age"] - feat["age"].mean()) / feat["age"].std(),
    completion_z=(feat["completion"] - feat["completion"].mean()) / feat["completion"].std()
)

# 4) Gestion des valeurs manquantes catégorielles
for col in ["gender", "region", "smoker_clean", "drinker_clean"]:
    mode_value = feat[col].replace("unknown", np.nan).mode()[0]
    feat[col] = feat[col].replace("unknown", np.nan).fillna(mode_value)

# 5) Encodage One-Hot
feat_encoded = pd.get_dummies(
    feat[["gender", "region", "smoker_clean", "drinker_clean"]],
    prefix=["gender", "region", "smoke", "drink"]
)


# 5) fusion des numériques
feat_encoded["age_z"] = feat["age_z"]
feat_encoded["completion_z"] = feat["completion_z"]

# 6) matrice X alignée sur l’ordre des nœuds
X = feat_encoded.reindex(H.nodes(), fill_value=0)

# ⚠️ 7) (RE)ATTACHE les attributs AUJOURD’HUI (après imputation/standardisation et après tout subgraph)
feat_attrs = feat[[
    "user_id","gender","region","smoker","drinker","completion",
    "smoker_clean","drinker_clean","age","age_z","completion_z"
]].copy()
feat_attrs["user_id"] = feat_attrs["user_id"].astype(int)

attrs = feat_attrs.set_index("user_id").to_dict("index")
nx.set_node_attributes(H, attrs)

print(f"OK: X = {X.shape}, attrs attached to H = {H.number_of_nodes()} nodes")
# Out:
# OK: X = (10681, 19), attrs attached to H = 10681 nodes

# %% [markdown]
# ### 💾 Étape 4 : Extraction de la composante géante et sauvegarde
#
# On conserve la plus grande composante connexe et
# on sauvegarde le graphe et la matrice de features pour les étapes GNN suivantes.

# %%
# ensure the dataset folder exists
os.makedirs("dataset", exist_ok=True)

# cast everything to numeric types Arrow can handle cleanly
X = X.astype("float32")

# save safely
import pickle
with open(GRAPH_PREP_PATH, "wb") as f:
    pickle.dump(H, f)

X.to_parquet(FEATURES_PREP_PATH)

print(f"🎯 Graphe sauvegardé → {GRAPH_PREP_PATH}")
print(f"🎯 Features sauvegardées → {FEATURES_PREP_PATH}")
# Out:
# 🎯 Graphe sauvegardé → dataset/pokec_graph_preprocessed.gpickle
# 🎯 Features sauvegardées → dataset/pokec_features_preprocessed.parquet

# %% [markdown]
# we view a node

# %%
# Show the first 5 nodes and their attached attributes
list(H.nodes(data=True))[:5]
# Out:
# [(131073,
#   {'gender': 'female',
#    'region': 'zilinsky kraj',
#    'smoker': nan,
#    'drinker': nan,
#    'completion': 17,
#    'smoker_clean': 'no',
#    'drinker_clean': 'no',
#    'age': 17.0,
#    'age_z': -0.657940081978753,
#    'completion_z': -1.5760497324355287}),
#  (32771,
#   {'gender': 'male',
#    'region': 'trenciansky kraj',
#    'smoker': nan,
#    'drinker': nan,
#    'completion': 17,
#    'smoker_clean': 'no',
#    'drinker_clean': 'no',
#    'age': 20.140809317604898,
#    'age_z': 0.0,
#    'completion_z': -1.5760497324355287}),
#  (229381,
#   {'gender': 'female',
#    'region': 'zahranicie',
#    'smoker': 'zakladne',
#    'drinker': 'modra,  fialova',
#    'completion': 78,
#    'smoker_clean': 'no',
#    'drinker_clean': 'no',
#    'age': 20.140809317604898,
#    'age_z': 0.0,
#    'completion_z': 0.9982077650594996}),
#  (229382,
#   {'gender': 'male',
#    'region': 'presovsky kraj',
#    'smoker': '██ ██ ██ ██',
#    'drinker': '██ ██ ██ ██',
# ...

# %% [markdown]
# ## 6️ Visualization (color by region)

# %%
import random
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Pick a random starting node
start = random.choice(list(H.nodes()))

# Get neighbors up to 2 hops away
connected_nodes = list(nx.single_source_shortest_path_length(H, start, cutoff=2).keys())
S = H.subgraph(connected_nodes).copy()

print(f"Visualizing connected subgraph: {S.number_of_nodes()} nodes, {S.number_of_edges()} edges")

# Layout + visualization
pos = nx.spring_layout(S, seed=42, iterations=30)

regions = [S.nodes[n].get("region", "unknown") for n in S.nodes()]
unique_regions = sorted(set(regions))
colors = plt.cm.tab20(np.linspace(0, 1, len(unique_regions)))
color_dict = {r: colors[i % 20] for i, r in enumerate(unique_regions)}
node_colors = [color_dict[S.nodes[n].get("region", "unknown")] for n in S.nodes()]

plt.figure(figsize=(10, 8))
nx.draw(
    S, pos,
    node_color=node_colors,
    node_size=40,
    edge_color="gray",
    with_labels=False,
    alpha=0.85
)
plt.title(f"Pokec Connected Subgraph ({S.number_of_nodes()} nodes) — colored by region")
plt.show()
# Out:
# Visualizing connected subgraph: 6890 nodes, 7168 edges

# %% [markdown]
# # Analyse Exploratoire du Graphe (AEG)
#
# Avant toute modélisation (GNN, prédiction de liens, etc.), on réalise une **analyse exploratoire du graphe**.
# Cette phase permet de comprendre la structure, l’importance des nœuds et la présence éventuelle de communautés.
#
# Les étapes suivantes sont :
# 1. Chargement du graphe prétraité
# 2. Analyse des propriétés globales (macro)
# 3. Étude des centralités (micro)
# 4. Détection de communautés et mesure d’assortativité (méso)

# %% [markdown]
# ### Chargement du graphe

# %%
import pickle
import networkx as nx
import pandas as pd

GRAPH_PREP_PATH = "dataset/pokec_graph_preprocessed.gpickle"
FEATURES_PREP_PATH = "dataset/pokec_features_preprocessed.parquet"

with open(GRAPH_PREP_PATH, "rb") as f:
    H = pickle.load(f)

X = pd.read_parquet(FEATURES_PREP_PATH)

print(f"Graphe chargé : {H.number_of_nodes()} nœuds, {H.number_of_edges()} arêtes")
print(f"Matrice de features : {X.shape[0]} lignes, {X.shape[1]} colonnes")
# Out:
# Graphe chargé : 10681 nœuds, 23726 arêtes
# Matrice de features : 10681 lignes, 19 colonnes

# %% [markdown]
# ## 1. Propriétés Globales du Graphe
#
# On mesure ici la **structure générale** du réseau :
# - Taille (nombre de nœuds et d’arêtes)
# - Densité
# - Coefficient de clustering global
# - Longueur moyenne du plus court chemin
# - Diamètre
# Ces métriques aident à caractériser le type de réseau (dense, clairsemé, petit monde, etc.).

# %%
import numpy as np
import random
import networkx as nx

# 1. Propriétés de base
N = H.number_of_nodes()
M = H.number_of_edges()
density = nx.density(H)
clustering = nx.transitivity(H)

# 2. Extraction de la plus grande composante connexe
largest_cc = max(nx.connected_components(H), key=len)
H_cc = H.subgraph(largest_cc).copy()

# 3. Approximation de la longueur moyenne du plus court chemin et du diamètre
# On échantillonne un sous-ensemble de nœuds pour accélérer le calcul
sample_size = min(2000, len(H_cc))  # on limite à 2000 nœuds max
sample_nodes = random.sample(list(H_cc.nodes()), sample_size)

distances = []
for n in sample_nodes:
    # Single-source shortest path lengths for node n
    sp_lengths = nx.single_source_shortest_path_length(H_cc, n)
    distances.extend(sp_lengths.values())

# Moyenne et percentiles comme approximation
avg_path_length = np.mean(distances)
diameter_approx = np.percentile(distances, 99.9)  # estimation du "diamètre"

# 4. Affichage des résultats
print(f"Nombre de nœuds : {N}")
print(f"Nombre d’arêtes : {M}")
print(f"Densité : {density:.6f}")
print(f"Clustering global : {clustering:.4f}")
print(f"Longueur moyenne approximée du plus court chemin : {avg_path_length:.3f}")
print(f"Diamètre approximé (99.9e percentile) : {diameter_approx:.0f}")
# Out:
# Nombre de nœuds : 10681
# Nombre d’arêtes : 23726
# Densité : 0.000416
# Clustering global : 0.0016
# Longueur moyenne approximée du plus court chemin : 2.982
# Diamètre approximé (99.9e percentile) : 6

# %% [markdown]
# # Étude de la Centralité du Graphe
#
# L’étude de la centralité vise à comprendre **le rôle structurel des nœuds** : quels sont les plus connectés, les plus influents ou les plus stratégiques dans le réseau.
#
# Nous allons calculer :
# - **Centralité de degré** (*degree centrality*)
# - **Centralité d’intermédiarité** (*betweenness centrality*)
# - **Centralité de proximité** (*closeness centrality*)
# - **PageRank**
# - **Centralité de vecteur propre** (*eigenvector centrality*)
#
# Toutes les mesures sont calculées sur la **plus grande composante connexe** du graphe pour éviter les biais dus aux sous-graphes isolés.

# %% [markdown]
# ### Préparation du graphe de travail

# %%
import networkx as nx

# On travaille sur la plus grande composante connexe
largest_cc = max(nx.connected_components(H), key=len)
H_cc = H.subgraph(largest_cc).copy()

print(f"Composante utilisée : {H_cc.number_of_nodes()} nœuds, {H_cc.number_of_edges()} arêtes")
# Out:
# Composante utilisée : 10681 nœuds, 23726 arêtes

# %% [markdown]
# ## 1. Centralité de Degré (Degree Centrality)
#
# La centralité de degré mesure la **popularité** d’un nœud, c’est-à-dire le nombre de connexions directes qu’il possède.
# C’est une mesure simple, mais souvent très révélatrice dans les réseaux sociaux.

# %%
degree_centrality = nx.degree_centrality(H_cc)
print(f"Centralité de degré calculée pour {len(degree_centrality)} nœuds.")

# Top 5
sorted_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:5]
for node, score in sorted_degree:
    print(f"Node {node}: degré centralité = {score:.4f}")
# Out:
# Centralité de degré calculée pour 10681 nœuds.
# Node 5935: degré centralité = 0.6450
# Node 7429: degré centralité = 0.0924
# Node 2230: degré centralité = 0.0846
# Node 224: degré centralité = 0.0244
# Node 189: degré centralité = 0.0234

# %% [markdown]
# ## 2. Centralité d’Intermédiarité (Betweenness Centrality)
#
# Cette mesure identifie les **nœuds-ponts**, qui relient des parties du graphe entre elles.
# Elle repose sur les plus courts chemins entre tous les couples de nœuds.
#
# Comme le calcul exact est coûteux sur de grands graphes, on utilise ici une **approximation par échantillonnage**.

# %%
betweenness_centrality = nx.betweenness_centrality(H_cc, k=1000, seed=42)  # approximation rapide
print(f"Centralité d’intermédiarité calculée (approximation sur 1000 nœuds).")

top_betw = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)[:5]
for node, score in top_betw:
    print(f"Node {node}: betweenness = {score:.4f}")
# Out:
# Centralité d’intermédiarité calculée (approximation sur 1000 nœuds).
# Node 5935: betweenness = 0.8628
# Node 2230: betweenness = 0.1432
# Node 7429: betweenness = 0.1290
# Node 7438: betweenness = 0.0563
# Node 224: betweenness = 0.0456

# %% [markdown]
# ## 3. Centralité de Proximité (Closeness Centrality)
#
# Cette mesure indique la **rapidité avec laquelle un nœud peut atteindre les autres**.
# Plus la distance moyenne vers les autres nœuds est faible, plus la centralité est élevée.

# %%
closeness_centrality = nx.closeness_centrality(H_cc)
print(f"Centralité de proximité calculée pour {len(closeness_centrality)} nœuds.")

top_close = sorted(closeness_centrality.items(), key=lambda x: x[1], reverse=True)[:5]
for node, score in top_close:
    print(f"Node {node}: closeness = {score:.4f}")
# Out:
# Centralité de proximité calculée pour 10681 nœuds.
# Node 5935: closeness = 0.6146
# Node 7438: closeness = 0.4827
# Node 224: closeness = 0.4669
# Node 39244: closeness = 0.4596
# Node 9370: closeness = 0.4503

# %% [markdown]
# ## 4. PageRank
#
# Le PageRank mesure l’**influence** d’un nœud : un nœud est important s’il est connecté à d’autres nœuds importants.
# C’est la mesure la plus utilisée dans les graphes dirigés (mais reste informative ici aussi).

# %%
pagerank = nx.pagerank(H_cc, alpha=0.85)
print(f"PageRank calculé pour {len(pagerank)} nœuds.")

top_pr = sorted(pagerank.items(), key=lambda x: x[1], reverse=True)[:5]
for node, score in top_pr:
    print(f"Node {node}: PageRank = {score:.4f}")
# Out:
# PageRank calculé pour 10681 nœuds.
# Node 5935: PageRank = 0.2573
# Node 2230: PageRank = 0.0324
# Node 7429: PageRank = 0.0167
# Node 189: PageRank = 0.0066
# Node 7607: PageRank = 0.0035

# %% [markdown]
# ## 5. Centralité de Vecteur Propre (Eigenvector Centrality)
#
# Cette mesure considère qu’un nœud est important s’il est connecté à d’autres nœuds importants.
# C’est une version plus mathématique du PageRank, basée sur la décomposition spectrale de la matrice d’adjacence.

# %%
try:
    eigen_centrality = nx.eigenvector_centrality_numpy(H_cc)
except nx.NetworkXError:
    eigen_centrality = nx.eigenvector_centrality(H_cc, max_iter=500)

print(f"Centralité de vecteur propre calculée pour {len(eigen_centrality)} nœuds.")

top_eig = sorted(eigen_centrality.items(), key=lambda x: x[1], reverse=True)[:5]
for node, score in top_eig:
    print(f"Node {node}: eigenvector = {score:.4f}")
# Out:
# Centralité de vecteur propre calculée pour 10681 nœuds.
# Node 5935: eigenvector = 0.7065
# Node 189: eigenvector = 0.0200
# Node 224: eigenvector = 0.0108
# Node 76: eigenvector = 0.0105
# Node 8514: eigenvector = 0.0099

# %% [markdown]
# ## 4. Corrélation entre les centralités et les attributs des utilisateurs
#
# Maintenant que nous avons calculé les mesures de centralité pour chaque nœud du graphe, nous allons :
# 1. Fusionner ces centralités avec les attributs utilisateurs (âge, genre, région, etc.).
# 2. Explorer leurs corrélations à l’aide de statistiques simples (Pearson).
# 3. Identifier quels facteurs démographiques ou comportementaux semblent liés à la position d’un utilisateur dans le réseau.

# %%
import pandas as pd

# Convertir les centralités en DataFrames et fusionner
centralities_df = pd.DataFrame({
    "node": list(H_cc.nodes()),
    "degree": [degree_centrality[n] for n in H_cc.nodes()],
    "betweenness": [betweenness_centrality[n] for n in H_cc.nodes()],
    "closeness": [closeness_centrality[n] for n in H_cc.nodes()],
    "pagerank": [pagerank[n] for n in H_cc.nodes()],
    "eigenvector": [eigen_centrality[n] for n in H_cc.nodes()],
})

# Extraire les attributs déjà attachés aux nœuds
attrs = pd.DataFrame.from_dict(dict(H_cc.nodes(data=True)), orient="index").reset_index()
attrs.rename(columns={"index": "node"}, inplace=True)

# Fusion
merged = pd.merge(centralities_df, attrs, on="node", how="inner")
print(f"Merged dataset: {merged.shape[0]} nodes, {merged.shape[1]} columns")
merged.head()
# Out:
# Merged dataset: 10681 nodes, 16 columns
#      node    degree  betweenness  closeness  pagerank  eigenvector  gender  \
# 0  131073  0.000094     0.000000   0.380681  0.000045     0.008503  female
# 1   32771  0.000094     0.000000   0.380681  0.000045     0.008503    male
# 2  229381  0.000094     0.000000   0.380681  0.000045     0.008503  female
# 3  229382  0.000094     0.000000   0.380681  0.000045     0.008503    male
# 4       7  0.001685     0.000872   0.329477  0.000174     0.000392  female
#
#              region       smoker          drinker  completion smoker_clean  \
# 0     zilinsky kraj          NaN              NaN          17           no
# 1  trenciansky kraj          NaN              NaN          17           no
# 2        zahranicie     zakladne  modra,  fialova          78           no
# 3    presovsky kraj  ██ ██ ██ ██      ██ ██ ██ ██          86           no
# 4     zilinsky kraj          NaN              NaN          12           no
#
# ...

# %% [markdown]
# ### Corrélations numériques : âge et completion
# Nous testons ici la corrélation de Pearson entre les variables numériques (âge, completion)
# et chacune des mesures de centralité.

# %%
from scipy.stats import pearsonr

num_cols = ["age", "completion"]
centrality_cols = ["degree", "betweenness", "closeness", "pagerank", "eigenvector"]

for y in centrality_cols:
    print(f"\n=== Corrélations avec {y} ===")
    for x in num_cols:
        valid = merged[[x, y]].dropna()
        r, p = pearsonr(valid[x], valid[y])
        print(f"{x:15s} r={r:.3f}  p={p:.4g}")
# Out:
# === Corrélations avec degree ===
# age             r=0.006  p=0.543
# completion      r=-0.014  p=0.1397
#
# === Corrélations avec betweenness ===
# age             r=0.004  p=0.7061
# completion      r=-0.014  p=0.1576
#
# === Corrélations avec closeness ===
# age             r=-0.230  p=8.844e-129
# completion      r=0.070  p=4.144e-13
#
# === Corrélations avec pagerank ===
# age             r=0.002  p=0.8376
# completion      r=-0.015  p=0.1155
#
# === Corrélations avec eigenvector ===
# age             r=-0.121  p=4.1e-36
# completion      r=0.017  p=0.07929

# %% [markdown]
# ### Analyse catégorielle : différence de centralité selon les attributs (ex : genre, région)
# On compare maintenant les moyennes de centralité entre groupes à l’aide de tests statistiques simples.

# %%
cat_cols = ["gender", "region", "smoker_clean", "drinker_clean"]

for cat in cat_cols:
    if cat in merged.columns:
        print(f"\n===== {cat.upper()} =====")
        print(merged.groupby(cat)[centrality_cols].mean().round(3).sort_values("pagerank", ascending=False))
# Out:
# ===== GENDER =====
#         degree  betweenness  closeness  pagerank  eigenvector
# gender
# female   0.000          0.0      0.340       0.0        0.005
# male     0.001          0.0      0.352       0.0        0.006
#
# ===== REGION =====
#                       degree  betweenness  closeness  pagerank  eigenvector
# region
# bratislavsky kraj      0.001        0.002      0.355     0.001        0.008
# banskobystricky kraj   0.001        0.000      0.312     0.000        0.003
# ceska republika        0.000        0.001      0.332     0.000        0.005
# kosicky kraj           0.000        0.000      0.364     0.000        0.007
# nan                    0.000        0.000      0.381     0.000        0.009
# nitriansky kraj        0.000        0.000      0.371     0.000        0.008
# presovsky kraj         0.000        0.000      0.371     0.000        0.008
# trenciansky kraj       0.000        0.000      0.369     0.000        0.008
# ...

# %% [markdown]
# # Étude comparative : modèles GNN pour prédire la centralité
#
# Cette section évalue plusieurs architectures de Graph Neural Networks (GCN, GraphSAGE, GAT)
# pour **prédire la centralité des nœuds** à partir des attributs démographiques et de la structure du graphe Pokec.
#
# Nous adoptons une méthodologie expérimentale rigoureuse :
# - **Séparation des données** en ensembles train/validation/test.
# - **Multiples exécutions** avec seeds différentes pour estimer la variance.
# - **Métriques** : RMSE (erreur), R² (variance expliquée), AUC (capacité à détecter les nœuds les plus centraux).
# - **Étude d’ablation** pour estimer l’importance des attributs.

# %%
# ============================================
# Conversion du graphe NetworkX vers PyTorch Geometric
# ============================================
import torch
from torch_geometric.utils import from_networkx

# Utiliser la composante connexe principale
G_nx = H_cc.copy()

# S'assurer que les indices de X correspondent bien aux noeuds du graphe
X_aligned = X.loc[list(G_nx.nodes())].sort_index()

# Conversion en tenseur
X_tensor = torch.tensor(X_aligned.to_numpy(), dtype=torch.float32)

# Sélection d'une variable cible de centralité (par ex. closeness)
# Vérifie d'abord que 'merged' contient bien les colonnes nécessaires
merged_aligned = merged.set_index("node").loc[list(G_nx.nodes())].sort_index()
y_tensor = torch.tensor(
    merged_aligned["closeness"].to_numpy(), dtype=torch.float32
).unsqueeze(1)

# Conversion NetworkX -> PyG
data_pyg = from_networkx(G_nx)
data_pyg.x = X_tensor
data_pyg.y = y_tensor

print(data_pyg)
# Out:
# Data(edge_index=[2, 47452], gender=[10681], region=[10681], smoker=[10681], drinker=[10681], completion=[10681], smoker_clean=[10681], drinker_clean=[10681], age=[10681], age_z=[10681], completion_z=[10681], num_nodes=10681, x=[10681, 19], y=[10681, 1])

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, SAGEConv, GATConv
from torch_geometric.transforms import RandomLinkSplit
from sklearn.metrics import r2_score, mean_squared_error, roc_auc_score
import numpy as np, pandas as pd, random

# -- Reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)

# -- Split data (modern PyG)
splitter = RandomLinkSplit(is_undirected=True, add_negative_train_samples=False,
                           num_val=0.1, num_test=0.1)
train_data, val_data, test_data = splitter(data_pyg)

def compute_auc(y_true, y_pred):
    try:
        thr = np.percentile(y_true, 90)
        y_bin = (y_true > thr).astype(int)
        return roc_auc_score(y_bin, y_pred)
    except Exception:
        return np.nan

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, SAGEConv, GATConv
from torch.nn import BatchNorm1d, Dropout


class GCN(torch.nn.Module):
    def __init__(self, in_dim, hidden, out_dim, dropout=0.3):
        super().__init__()
        self.conv1 = GCNConv(in_dim, hidden)
        self.norm1 = BatchNorm1d(hidden)
        self.conv2 = GCNConv(hidden, out_dim)
        self.drop = Dropout(dropout)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.norm1(x)
        x = self.drop(x)
        x = self.conv2(x, edge_index)
        return x

    def get_embeddings(self, x, edge_index):
        """Return hidden representations before the last layer."""
        x = F.relu(self.conv1(x, edge_index))
        x = self.norm1(x)
        return x.detach()


class GraphSAGE(torch.nn.Module):
    def __init__(self, in_dim, hidden, out_dim, dropout=0.3):
        super().__init__()
        self.conv1 = SAGEConv(in_dim, hidden)
        self.norm1 = BatchNorm1d(hidden)
        self.conv2 = SAGEConv(hidden, out_dim)
        self.drop = Dropout(dropout)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.norm1(x)
        x = self.drop(x)
        x = self.conv2(x, edge_index)
        return x

    def get_embeddings(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.norm1(x)
        return x.detach()


class GAT(torch.nn.Module):
    def __init__(self, in_dim, hidden, out_dim, heads=2, dropout=0.3):
        super().__init__()
        self.conv1 = GATConv(in_dim, hidden, heads=heads, dropout=dropout)
        self.norm1 = BatchNorm1d(hidden * heads)
        self.conv2 = GATConv(hidden * heads, out_dim, heads=1, dropout=dropout)
        self.drop = Dropout(dropout)

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index))
        x = self.norm1(x)
        x = self.drop(x)
        x = self.conv2(x, edge_index)
        return x

    def get_embeddings(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index))
        x = self.norm1(x)
        return x.detach()

# %%
import torch
import torch.nn.functional as F
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score, mean_squared_error, roc_auc_score


# ---------------------------
# 1️⃣ TRAINING FUNCTION
# ---------------------------
def train_model(model, optimizer, data, epochs=150):
    """
    Train a GNN regression model on node-level centrality prediction.
    Handles shape mismatches and ensures sklearn compatibility.
    """
    model.train()
    for epoch in range(epochs):
        optimizer.zero_grad()
        out = model(data.x, data.edge_index).view(-1, 1)
        y = data.y.view(-1, 1)

        loss = F.mse_loss(out, y)
        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            print(f"Epoch {epoch:03d} | Loss: {loss.item():.4f}")

    # Evaluation phase
    model.eval()
    with torch.no_grad():
        preds = model(data.x, data.edge_index).view(-1).cpu().numpy()
        y_true = data.y.view(-1).cpu().numpy()

        r2 = r2_score(y_true, preds)
        rmse = np.sqrt(mean_squared_error(y_true, preds))
        print(f"Final R²: {r2:.3f} | RMSE: {rmse:.4f}")

    return model


# ---------------------------
# 2️⃣ WRAPPER TO TRAIN/EVAL MULTIPLE MODELS
# ---------------------------
def train_and_evaluate(model_class, name, lr=0.01, hidden=64, epochs=150):
    model = model_class(in_dim=data_pyg.num_features, hidden=hidden, out_dim=1)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=5e-4)
    train_model(model, optimizer, data_pyg, epochs=epochs)

    # Evaluate
    model.eval()
    with torch.no_grad():
        preds = model(data_pyg.x, data_pyg.edge_index).view(-1).cpu().numpy()
        y_true = data_pyg.y.view(-1).cpu().numpy()
        r2 = r2_score(y_true, preds)
        rmse = np.sqrt(mean_squared_error(y_true, preds))

        # AUC optional if you have binary task; fallback otherwise
        try:
            auc = roc_auc_score((y_true > np.median(y_true)).astype(int), preds)
        except ValueError:
            auc = np.nan

    results = pd.DataFrame([{"Model": name, "R²": r2, "RMSE": rmse, "AUC": auc}])
    return results

# %%
# Train and evaluate all three models
results_gcn = train_and_evaluate(GCN, "GCN")
results_sage = train_and_evaluate(GraphSAGE, "GraphSAGE")
results_gat = train_and_evaluate(GAT, "GAT")

# Comparison table
compare = pd.DataFrame({
    "Modèle": ["GCN", "GraphSAGE", "GAT"],
    "RMSE_moyen": [results_gcn["RMSE"].mean(), results_sage["RMSE"].mean(), results_gat["RMSE"].mean()],
    "R²_moyen": [results_gcn["R²"].mean(), results_sage["R²"].mean(), results_gat["R²"].mean()],
    "AUC_moyen": [results_gcn["AUC"].mean(), results_sage["AUC"].mean(), results_gat["AUC"].mean()],
}).round(4)

# Identify best-performing model
best_name = compare.loc[compare["R²_moyen"].idxmax(), "Modèle"]
print(f"Best-performing model: {best_name}")

# Instantiate the best model using your argument names
if best_name == "GCN":
    best_model = GCN(in_dim=data_pyg.num_features, hidden=64, out_dim=1)
elif best_name == "GraphSAGE":
    best_model = GraphSAGE(in_dim=data_pyg.num_features, hidden=64, out_dim=1)
else:
    best_model = GAT(in_dim=data_pyg.num_features, hidden=64, out_dim=1)

# Retrain the chosen model on the full dataset
optimizer = torch.optim.Adam(best_model.parameters(), lr=0.01)
train_model(best_model, optimizer, data_pyg)

# Keep the original node features for embedding visualization
X_full = data_pyg.x.clone()
# Out:
# === GCN ===
#          RMSE      R²     AUC
# count  3.0000  3.0000  3.0000
# mean   0.0528  0.0158  0.4543
# std    0.0001  0.0038  0.0205
# min    0.0527  0.0135  0.4412
# 25%    0.0528  0.0136  0.4425
# 50%    0.0528  0.0138  0.4438
# 75%    0.0528  0.0170  0.4608
# max    0.0529  0.0202  0.4779
#
# === GraphSAGE ===
#          RMSE      R²     AUC
# count  3.0000  3.0000  3.0000
# mean   0.0640 -0.4493  0.4943
# std    0.0016  0.0713  0.0061
# min    0.0623 -0.5112  0.4903
# 25%    0.0634 -0.4883  0.4908
# 50%    0.0644 -0.4654  0.4912
# 75%    0.0649 -0.4183  0.4963
# max    0.0654 -0.3713  0.5013
#
# === GAT ===
#         RMSE      R²     AUC
# count  3.000  3.0000  3.0000
# mean   0.053  0.0086  0.4683
# std    0.000  0.0015  0.0097
# min    0.053  0.0068  0.4572
# 25%    0.053  0.0081  0.4648
# 50%    0.053  0.0094  0.4723
# 75%    0.053  0.0095  0.4739
# max    0.053  0.0095  0.4754
# Best-performing model: GCN
# Epoch 000 | Loss: 0.5474
# Epoch 010 | Loss: 0.1091
# ...

# %%
feature_sets = {
    "full": ["age_z", "completion_z"],
    "age_only": ["age_z"],
    "completion_only": ["completion_z"],
    "none": []
}

abl_results = []

for name, cols in feature_sets.items():
    if len(cols) == 0:
        data_pyg.x = torch.ones((data_pyg.num_nodes, 1))
    else:
        data_pyg.x = torch.tensor(merged[cols].to_numpy(), dtype=torch.float)

    df = train_and_evaluate(GCN, f"GCN-{name}")
    abl_results.append({
        "Configuration": name,
        "RMSE": df["RMSE"].mean(),
        "R²": df["R²"].mean(),
        "AUC": df["AUC"].mean(),
    })

abl_df = pd.DataFrame(abl_results).round(4)
display(abl_df)
# Out:
# === GCN-full ===
#          RMSE      R²     AUC
# count  3.0000  3.0000  3.0000
# mean   0.0528  0.0158  0.4543
# std    0.0001  0.0038  0.0205
# min    0.0527  0.0135  0.4412
# 25%    0.0528  0.0136  0.4425
# 50%    0.0528  0.0138  0.4438
# 75%    0.0528  0.0170  0.4608
# max    0.0529  0.0202  0.4779
#
# === GCN-age_only ===
#          RMSE      R²     AUC
# count  3.0000  3.0000  3.0000
# mean   0.0528  0.0158  0.4543
# std    0.0001  0.0038  0.0205
# min    0.0527  0.0135  0.4412
# 25%    0.0528  0.0136  0.4425
# 50%    0.0528  0.0138  0.4438
# 75%    0.0528  0.0170  0.4608
# max    0.0529  0.0202  0.4779
#
# === GCN-completion_only ===
#          RMSE      R²     AUC
# count  3.0000  3.0000  3.0000
# mean   0.0528  0.0158  0.4543
# std    0.0001  0.0038  0.0205
# min    0.0527  0.0135  0.4412
# 25%    0.0528  0.0136  0.4425
# 50%    0.0528  0.0138  0.4438
# 75%    0.0528  0.0170  0.4608
# max    0.0529  0.0202  0.4779
#
# === GCN-none ===
#          RMSE      R²     AUC
# ...

# %% [markdown]
# ## Visualisation des embeddings appris
#
# Nous projetons les embeddings finaux des nœuds dans un espace 2D via **t-SNE** et **UMAP**.
# L’objectif est de visualiser si la structure apprise par le modèle (GCN ici) capture des motifs
# sociaux ou démographiques (ex : âge, région).

# %%
from sklearn.manifold import TSNE
import umap
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

best_model.eval()
data_pyg.x = X_full.clone()

# ---- Compute embeddings ----
with torch.no_grad():
    embeddings = best_model(data_pyg.x, data_pyg.edge_index).cpu().numpy()

# ---- Meta data for coloring ----
meta = merged[["region", "age_z"]].reset_index(drop=True)

# ---- Case 1: embeddings are 1D (scalar output, e.g. regression) ----
if embeddings.ndim == 1 or embeddings.shape[1] == 1:
    plt.figure(figsize=(8, 6))
    sns.histplot(embeddings.squeeze(), bins=50, kde=True, color="skyblue")
    plt.title("Distribution des valeurs de centralité prédites")
    plt.xlabel("Valeur prédite (embedding 1D)")
    plt.ylabel("Fréquence")
    plt.tight_layout()
    plt.show()

# ---- Case 2: embeddings multidimensionnels (ex: 16D, 32D, etc.) ----
else:
    # Downsample for speed
    max_points = 5000
    if embeddings.shape[0] > max_points:
        idx = np.random.choice(embeddings.shape[0], max_points, replace=False)
        emb_sample = embeddings[idx]
        meta_sample = meta.iloc[idx].reset_index(drop=True)
    else:
        emb_sample = embeddings
        meta_sample = meta

    # t-SNE & UMAP
    tsne_emb = TSNE(n_components=2, random_state=42, perplexity=30).fit_transform(emb_sample)
    umap_emb = umap.UMAP(n_components=2, random_state=42).fit_transform(emb_sample)

    # Plot
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    sns.scatterplot(
        x=tsne_emb[:, 0], y=tsne_emb[:, 1],
        hue=meta_sample["region"], s=10, ax=axes[0], legend=False
    )
    axes[0].set_title("t-SNE des embeddings (colorés par région)")

    sns.scatterplot(
        x=umap_emb[:, 0], y=umap_emb[:, 1],
        hue=meta_sample["age_z"], s=10, palette="coolwarm", ax=axes[1], legend=False
    )
    axes[1].set_title("UMAP des embeddings (colorés par âge)")

    plt.tight_layout()
    plt.show()

# %%
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Similarité cosinus entre embeddings (échantillon pour éviter les OOM)
sample_idx = np.random.choice(len(embeddings), size=500, replace=False)
emb_sample = embeddings[sample_idx]
meta_sample = merged.iloc[sample_idx][["region", "age_z"]]

sim_matrix = cosine_similarity(emb_sample)

# Visualisation : heatmap triée par région
sorted_idx = np.argsort(meta_sample["region"])
sns.heatmap(sim_matrix[sorted_idx][:, sorted_idx], cmap="viridis", cbar=True)
plt.title("Similarité cosinus entre embeddings (triée par région)")
plt.show()

# Moyenne de similarité intra/inter-régions
meta_sample["region"] = meta_sample["region"].astype(str)
group_sim = []
for region in meta_sample["region"].unique():
    idx = meta_sample["region"] == region
    intra = sim_matrix[np.ix_(idx, idx)].mean()
    inter = sim_matrix[np.ix_(idx, ~idx)].mean()
    group_sim.append({"region": region, "intra": intra, "inter": inter})

pd.DataFrame(group_sim).sort_values("intra", ascending=False)
# Out:
#                  region  intra  inter
# 0       nitriansky kraj    1.0    1.0
# 1        presovsky kraj    1.0    1.0
# 2  banskobystricky kraj    1.0    1.0
# 3         trnavsky kraj    1.0    1.0
# 4          kosicky kraj    1.0    1.0
# 5      trenciansky kraj    1.0    1.0
# 6     bratislavsky kraj    1.0    1.0
# 7            zahranicie    1.0    1.0
# 8         zilinsky kraj    1.0    1.0
# 9       ceska republika    1.0    1.0

# %% [markdown]
# ## Prédiction de liens — test d’homophilie
#
# Nous ajoutons ici une tâche de **Link Prediction** :
# le modèle doit prédire si deux utilisateurs devraient être connectés.
# Cette expérience permet de vérifier si la structure et les attributs des nœuds
# encodent bien des similarités sociales (homophilie : "qui se ressemble se connecte").

# %%
from torch_geometric.utils import negative_sampling
from sklearn.metrics import roc_auc_score

# Utiliser le bon modèle et les features complets
best_model.eval()
data_pyg.x = X_full  # on remet les features standardisés complets

with torch.no_grad():
    z = best_model(data_pyg.x, data_pyg.edge_index)

# Positives = arêtes existantes
pos_edge_index = data_pyg.edge_index

# Négatives = arêtes absentes (échantillonnées)
neg_edge_index = negative_sampling(
    pos_edge_index,
    num_nodes=data_pyg.num_nodes,
    num_neg_samples=pos_edge_index.size(1),
)

# Fonction utilitaire : produit scalaire entre embeddings de deux nœuds
def link_logits(z, edge_index):
    return (z[edge_index[0]] * z[edge_index[1]]).sum(dim=-1)

# Calcul des scores pour les liens existants / absents
with torch.no_grad():
    pos_score = torch.sigmoid(link_logits(z, pos_edge_index)).cpu().numpy()
    neg_score = torch.sigmoid(link_logits(z, neg_edge_index)).cpu().numpy()

# Labels + Prédictions concaténées
y_true = np.concatenate([
    np.ones_like(pos_score),
    np.zeros_like(neg_score)
])
y_pred = np.concatenate([pos_score, neg_score])

auc = roc_auc_score(y_true, y_pred)
print(f"AUC (homophilie des liens) : {auc:.4f}")
# Out:
# AUC (homophilie des liens) : 0.3731

# %% [markdown]
# ## Détection de communautés : Louvain vs Embeddings
#
# Nous comparons la détection de communautés purement structurelle (**Louvain**)
# avec un clustering effectué sur les embeddings appris par le modèle.
# L’objectif est d’évaluer si les **embeddings capturent la modularité** du graphe.

# %%
import community as community_louvain
from sklearn.cluster import KMeans
from sklearn.metrics import normalized_mutual_info_score

# Conversion PyG -> NetworkX (graphe non dirigé)
edges = data_pyg.edge_index.cpu().numpy()
G_nx = nx.Graph()
G_nx.add_edges_from(edges.T)

# Détection de communautés Louvain
louvain_partition = community_louvain.best_partition(G_nx)
louvain_labels = np.array(list(louvain_partition.values()))

# Clustering sur les embeddings appris (issus de best_model)
k = len(np.unique(louvain_labels))
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
kmeans_labels = kmeans.fit_predict(embeddings)

# Comparaison Louvain ↔ KMeans (embeddings)
nmi = normalized_mutual_info_score(louvain_labels, kmeans_labels)
print(f"NMI entre Louvain et KMeans sur embeddings : {nmi:.3f}")
# Out:
# NMI entre Louvain et KMeans sur embeddings : 0.022
